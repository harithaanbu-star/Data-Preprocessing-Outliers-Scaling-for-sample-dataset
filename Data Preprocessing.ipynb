# %%
import pandas as pd  # data logic of patter , solve problem , decision making , improves ---> machine learning

# %%
df=pd.read_csv('preprocessing_dataset.csv')
df1=df.copy()

# %%
df2=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
lb.fit_transform(df['Gender']) # To 
df
# Out:
#       Name    Age Gender   Salary Department
# 0    Alice   25.0      F  50000.0         HR
# 1      Bob   30.0      M  60000.0    Finance
# 2  Charlie    NaN      M  55000.0         IT
# 3    David   40.0      M  58000.0         HR
# 4      Eve   22.0      F  52000.0         IT
# 5    Frank   35.0    NaN  61000.0    Finance
# 6    Grace  120.0      F      NaN    Finance
# 7    Henry   28.0      M  59000.0         HR
# 8      Ivy   29.0      F  63000.0         IT
# 9     Jack   27.0      M  62000.0    Finance

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Encoded Gender']=lb.fit_transform(df['Gender']) # To identify the difference
df
# Out:
#       Name    Age Gender   Salary Department  Encoded Gender
# 0    Alice   25.0      F  50000.0         HR               0
# 1      Bob   30.0      M  60000.0    Finance               1
# 2  Charlie    NaN      M  55000.0         IT               1
# 3    David   40.0      M  58000.0         HR               1
# 4      Eve   22.0      F  52000.0         IT               0
# 5    Frank   35.0    NaN  61000.0    Finance               2
# 6    Grace  120.0      F      NaN    Finance               0
# 7    Henry   28.0      M  59000.0         HR               1
# 8      Ivy   29.0      F  63000.0         IT               0
# 9     Jack   27.0      M  62000.0    Finance               1

# %%
from sklearn.preprocessing import OneHotEncoder 
oh=OneHotEncoder(sparse_output=False)  # takes all data as array  and easy understanding
df['Encoded Gender']=oh.fit_transform(df[['Gender']]) 
df
# Out:
#       Name    Age Gender   Salary Department  Encoded Gender
# 0    Alice   25.0      F  50000.0         HR             1.0
# 1      Bob   30.0      M  60000.0    Finance             0.0
# 2  Charlie    NaN      M  55000.0         IT             0.0
# 3    David   40.0      M  58000.0         HR             0.0
# 4      Eve   22.0      F  52000.0         IT             1.0
# 5    Frank   35.0    NaN  61000.0    Finance             0.0
# 6    Grace  120.0      F      NaN    Finance             1.0
# 7    Henry   28.0      M  59000.0         HR             0.0
# 8      Ivy   29.0      F  63000.0         IT             1.0
# 9     Jack   27.0      M  62000.0    Finance             0.0

# %%
from sklearn.preprocessing import OneHotEncoder 
oh=OneHotEncoder(sparse_output=True)  #  Take as sparse matrix and takes ony non zero values difficult understanding
df[['Gen1','Gen2']]=oh.fit_transform(df[['Gender']])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\2644385362.py in ?()
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 oh=OneHotEncoder(sparse_output=True)  #  Take as sparse matrix and takes ony non zero values difficult understanding
# ----> 3 df[['Gen1','Gen2']]=oh.fit_transform(df[['Gender']])
#       4 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#    4302         elif (
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4351
#    4352             elif np.ndim(value) > 1:
#    4353                 # list of lists
#    4354                 value = DataFrame(value).values
# -> 4355                 return self._setitem_array(key, value)
#    4356
#    4357             else:
#    4358                 self._iset_not_inplace(key, value)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4346                 for col in key:
#    4347                     self[col] = value
#    4348
#    4349             elif isinstance(value, np.ndarray) and value.ndim == 2:
# -> 4350                 self._iset_not_inplace(key, value)
#    4351
#    4352             elif np.ndim(value) > 1:
#    4353                 # list of lists
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4373                 return obj[i]
#    4374
#    4375         if self.columns.is_unique:
#    4376             if np.shape(value)[-1] != len(key):
# -> 4377                 raise ValueError("Columns must be same length as key")
#    4378
#    4379             for i, col in enumerate(key):
#    4380                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key

# %%
#get dummies
df11=pd.get_dummies(df,columns=['Gender'],drop_first=True) #Drop 
df11
# Out:
#       Name    Age   Salary Department  Encoded Gender  Gender_M
# 0    Alice   25.0  50000.0         HR             1.0     False
# 1      Bob   30.0  60000.0    Finance             0.0      True
# 2  Charlie    NaN  55000.0         IT             0.0      True
# 3    David   40.0  58000.0         HR             0.0      True
# 4      Eve   22.0  52000.0         IT             1.0     False
# 5    Frank   35.0  61000.0    Finance             0.0     False
# 6    Grace  120.0      NaN    Finance             1.0     False
# 7    Henry   28.0  59000.0         HR             0.0      True
# 8      Ivy   29.0  63000.0         IT             1.0     False
# 9     Jack   27.0  62000.0    Finance             0.0      True

# %%
# Ordinal Encoding
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df1['Encoded Gender']=oe.fit_transform(df[['Gender']])
df1
# Out:
#       Name    Age Gender   Salary Department  Encoded Gender
# 0    Alice   25.0      F  50000.0         HR             0.0
# 1      Bob   30.0      M  60000.0    Finance             1.0
# 2  Charlie    NaN      M  55000.0         IT             1.0
# 3    David   40.0      M  58000.0         HR             1.0
# 4      Eve   22.0      F  52000.0         IT             0.0
# 5    Frank   35.0    NaN  61000.0    Finance             NaN
# 6    Grace  120.0      F      NaN    Finance             0.0
# 7    Henry   28.0      M  59000.0         HR             1.0
# 8      Ivy   29.0      F  63000.0         IT             0.0
# 9     Jack   27.0      M  62000.0    Finance             1.0
